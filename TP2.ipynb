# %% [markdown]
# <img src="images/isitcomlogo.png" align="right" width="167" height="89" >

# %% [markdown]
# # <FONT color="#253186">Compte Rendu TP2:</FONT>

# %% [markdown]
# ## <FONT color="#4E93E5">Réalisé par : Ahmed KHALIFA                                                                2DNI2</FONT>

# %% [markdown]
# ## <span style="color:#FF5733"> Exercice 1 :

# %% [markdown]
# **Polynome d'interpolation de Lagrange**
# > Soient $(x_0,y_0), \ldots,(x_k,y_k),\ldots ,(x_n,k_n)$ $n+1$ points deux à deux distincts, le polynôme d'interpolation de Lagrange associés à ces points supports est défini par :
# > $$P_n(x)=\sum_{k=0}^{n-1} y_kL_k(x)$$
#
# avec $L_{0}(x)=\displaystyle\frac{(x-x_1)(x-x_2)\ldots(x-x_{n})}{(x_0-x_1)(x_0-x_2)\ldots(x_0-x_{n})}$ et $L_{k}(x)=\displaystyle\frac{(x-x_1)(x-x_2)\ldots(x-x_{k-1})(x-x_{k+1})\ldots(x_0-x_{n})}{(x_k-x_0)(x_k-x_1)\ldots(x_k-x_{k-1})(x_k-x_{k+1})\ldots(x_k-x_{n})}$ pour $k\in \{1,\ldots,n\}$

# %%
from numpy import prod
def pr(x,y,c):
    S = [] 
    n = len(x)
    
    for j in range(n):
        L =[c-xx for xx in x]
        for k in range(n):
            if (k == j):                
                L[k] = 1
            else:
                L[k] = L[k]/(x[j] - x[k])   
        S.append(y[j]*prod(L))
        
    return  sum(S)

# %%
X=[1 ,2 ,3 ,4]
Y=[-1, 0, 2 ,1]
for i in X:
    print(pr(X,Y,i))
sum(X)
# Out:
# -1.0
# 0.0
# 2.0
# 1.0
# 10

# %% [markdown]
# ### La fonction va calculer le polynôme d'interpolation de Lagrange pour les deux vecteur X et Y, L(x)= 10

# %%
x=[1,2,3,4]
y=[-1,0,2,1]

# %%
def pr_2(x,y,c):
    S = [] 
    n = len(x)
    for c in x:
            for j in range(n):
                L =[c-xx for xx in x]
                for k in range(n):
                    if (k == j):                
                        L[k] = 1
                    else:
                        L[k] = L[k]/(x[j] - x[k])   
                S.append(y[j]*prod(L))

            return L[3]

# %%
for i in X:
    print(pr_2(X,Y,i))
# Out:
# 1
# 1
# 1
# 1

# %% [markdown]
# ### 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
pn=[]
x=np.arange(-1,1,0.1)
f= lambda x:1/(1+x**2)
y=f(x)
t=np.linspace(-1,1,100)
for i in range(len(t)):
    pn.append(pr(x,y,t[i]))
plt.plot(t,pn,"g",x,y,"bo",t,f(t),"y")
plt.show()

# %% [markdown]
# 4) On considère la fonction $F$ suivante :
# $$
# F(h) = \pi -\cos \left(\frac{h}{2}\right) + h \sqrt{1-\left(\frac{h}{2}\right)^2}, \qquad
# h\in [0,2],
# $$
# et les points d'interpolation $x_i = ih$, $0\leq i\leq n$, avec $ n=20$ et $h=0.1$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
pt=[]
x=np.arange(0,3)
f= lambda x:math.pi-math.cos(x/2)+x*math.sqrt(1-(x/2)**2)
f_2=np.vectorize(f)
y=f_2(x)
t=np.linspace(-1,1,100)
for i in range(len(t)):
    pt.append(pr(x,y,t[i]))
plt.plot(t,pt,"g",x,y,"bo",t,f_2(t),"y")
plt.show()

# %%
plt.plot(t,f_2(t)-pt,"g")
plt.show()

# %% [markdown]
# ## <span style="color:#FF5733">Exercice 2 : ( Phenomène de Runge )

# %%
N=7
X=np.linspace(-5,5,N)
f= lambda x:1/(1+x**2)
Y=f(X);
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.plot(t,f(t),'g',X,Y,'ob', t, np.polyval(p,t),'y')
plt.title("Interpolation Equidistante avec N=7")
# Out:
# Text(0.5,1,'Interpolation Equidistante avec N=7')

# %%
N=8
X=np.linspace(-5,5,N)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000);
plt.plot(t,f(t),'g',X,Y,'ob', t, np.polyval(p,t),'y')
plt.title("Interpolation Equidistante avec N=8")
# Out:
# Text(0.5,1,'Interpolation Equidistante avec N=8')

# %%
N=9
X=np.linspace(-5,5,N)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.plot(t,f(t),'g',X,Y,'ob', t, np.polyval(p,t),'y')
plt.title("Interpolation Equidistante avec N=9")
# Out:
# Text(0.5,1,'Interpolation Equidistante avec N=9')

# %%
N=10
X=np.linspace(-5,5,N)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.plot(t,f(t),'g',X,Y,'ob', t, np.polyval(p,t),'y')
plt.title("Interpolation Equidistante avec N=10")
# Out:
# Text(0.5,1,'Interpolation Equidistante avec N=10')

# %% [markdown]
# ### 2) Les points de Tchebycheff sur un intervalle $[a;b]$ sont définie par :$$x_k=\dfrac{a+b}{2}+\dfrac{a-b}{2}\cos\left(\frac{k-1}{n-1}\pi\right)\hspace{0.5cm} (k=1,..,n: x_1=a:x_n=b)$$

# %%
def tcheb(a,b,n):
    v=[]
    for k in range(n):
        v.append((a+b)/2+(a-b)/2*math.cos((k-1)/(n-1)*math.pi))
    return v

# %%
tcheb(-5,5,11)
# Out:
# [-4.755282581475767,
#  -5.0,
#  -4.755282581475767,
#  -4.045084971874737,
#  -2.938926261462366,
#  -1.5450849718747373,
#  -3.061616997868383e-16,
#  1.5450849718747368,
#  2.938926261462365,
#  4.045084971874736,
#  4.755282581475767]

# %%
N=10
Yt=[]
f= lambda x:1/(1+x**2)
Xt=tcheb(-7,7,N)
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1)
plt.plot(t,f(t),'g',Xt,Yt,'ob', t, np.polyval(pt,t),'y')
plt.title("Interpolation Tchebycheff avec N=%i"%N)
# Out:
# C:\Users\Administrateur\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RankWarning: Polyfit may be poorly conditioned
#   import sys
# Text(0.5,1,'Interpolation Tchebycheff avec N=10')

# %%
N=11
Yt=[]
f= lambda x:1/(1+x**2)
Xt=tcheb(-7,7,N)
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N)
plt.plot(t,f(t),'g',Xt,Yt,'ob', t, np.polyval(pt,t),'y')
plt.title("Interpolation Tchebycheff avec N=%i"%N)
# Out:
# C:\Users\Administrateur\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RankWarning: Polyfit may be poorly conditioned
#   import sys
# Text(0.5,1,'Interpolation Tchebycheff avec N=11')

# %%
N=16
Yt=[]
f= lambda x:1/(1+x**2)
Xt=tcheb(-7,7,N)
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1)
plt.plot(t,f(t),'g',Xt,Yt,'ob', t, np.polyval(pt,t),'y')
plt.title("Interpolation Tchebycheff avec N=%i"%N)
# Out:
# C:\Users\Administrateur\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RankWarning: Polyfit may be poorly conditioned
#   import sys
# Text(0.5,1,'Interpolation Tchebycheff avec N=16')

# %%
N=17
Yt=[]
f= lambda x:1/(1+x**2)
Xt=tcheb(-7,7,N)
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1)
plt.plot(t,f(t),'g',Xt,Yt,'ob', t, np.polyval(pt,t),'y')
plt.title("Interpolation Tchebycheff avec N=%i"%N)
# Out:
# C:\Users\Administrateur\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RankWarning: Polyfit may be poorly conditioned
#   import sys
# Text(0.5,1,'Interpolation Tchebycheff avec N=17')

# %% [markdown]
# ## <span style="color:#FF5733"> Exercice 3 :

# %% [markdown]
# ###  1) Déterminer en utilisant les deux codes puis par un calcul à la main le polynôme de Newton pour les données suivantes :
#
#
# <center>
# <table>
#       $\begin{array}{|c|c|c|}
#    \hline
#    i & x_i  & y_i \\
#    \hline
#    0 &   -1  &   6 \\
#    1 &   0 &  1 \\
#    2 &  2  &  3 \\
#    3 &  5  &  66 \\
#    \hline
# \end{array}$
# </table>
# </center>

# %%
def intN(x,y):
    m=len(x)
    f=np.zeros(m)
    for k in range(1,m):
        f[k:m+1]=np.array(np.array(y[k:m+1])-np.array(y[k-1:m-1]))/np.array(np.array(x[k:m+1])-np.array(x[0:m-k]))
    return f

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
intN(x,y)
# Out:
# array([ 0.        , -5.        ,  0.66666667, 10.5       ])

# %%
def intNval(x,y,t):
    m=len(x)
    p=y[m-1]*np.ones(len(t))
    for k in range(m-2,-1,-1):
        p=p*np.array((np.array(t)-x[k]))+y[k]
    return p

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
t=[0,1,2,3]
intNval(x,y,t)
# Out:
# array([   7., -118.,   27.,  838.])

# %% [markdown]
# ## calcule a la main :

# %% [markdown]
# <img src="images/Newton.jpg" width="269" height="500" >

# %% [markdown]
# ### 2) Donner le Graph du polynôme trouvé en 1) dans l'intervalle  [−1;5] :

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
f=intN(x,y)
plt.plot(x,f,'g',x,y,'ob')
plt.show()

# %% [markdown]
# ### 3) Calculer  P(1)  en utilisant le polynôme trouvé en 1).

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
t=[0,1,2,3]
p=intNval(x,y,t)
p[0]
# Out:
# 7.0
